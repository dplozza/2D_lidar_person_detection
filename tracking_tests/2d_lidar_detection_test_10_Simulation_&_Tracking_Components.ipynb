# %%
# %matplotlib inline

# %% [markdown]
# # 10 - Tracking in simulation: bringing all components together
# The previous tutorials have introduced various aspects of Stone Soup covering inference and data
# association for multiple-target trackers, using simulated data. This tutorial consolidates those
# aspects in a notebook which can be modified to individual need. It contains all aspects
# introduced in previous tutorials, and nothing new.

# %% [markdown]
# ## Process
# This notebook, as with the previous, proceeds according to the following steps:
#
# 1. Create the simulation
#
#   * Initialise the 'playing field'
#   * Choose number of targets and initial states
#   * Create some transition models
#   * Create some sensor models
#
# 2. Initialise the tracker components
#
#   * Initialise predictors
#   * Initialise updaters
#   * Initialise data associations, hypothesisers
#   * Initiators and deleters
#   * Create the tracker
#
# 3. Run the tracker
#
#   * Plot the output

# %% [markdown]
# ## Create the simulation

# %% [markdown]
# Separate out the imports

# %%
import numpy as np
import datetime

# %% [markdown]
# ### Initialise ground truth
# Here are some configurable parameters associated with the ground truth, e.g. defining where
# tracks are born and at what rate, death probability. This follows similar logic to the code
# in previous tutorial section `auto_tutorials/09_Initiators_&_Deleters:Simulating Multiple
# Targets`.

# %%
from stonesoup.types.array import StateVector, CovarianceMatrix
from stonesoup.types.state import GaussianState
initial_state_mean = StateVector([[0], [0], [0], [0]])
initial_state_covariance = CovarianceMatrix(np.diag([4, 0.5, 4, 0.5]))
timestep_size = datetime.timedelta(seconds=5)
number_of_steps = 20
birth_rate = 0.3
death_probability = 0.05
initial_state = GaussianState(initial_state_mean, initial_state_covariance)

# %% [markdown]
# ## Transition model

# %% [markdown]
# Create the transition model - default set to 2d nearly-constant velocity with small (0.05)
# variance.

# %%
from stonesoup.models.transition.linear import (
    CombinedLinearGaussianTransitionModel, ConstantVelocity)
transition_model = CombinedLinearGaussianTransitionModel(
    [ConstantVelocity(0.05), ConstantVelocity(0.05)])

# %% [markdown]
# Put this all together in a multi-target simulator.

# %%
from stonesoup.simulator.simple import MultiTargetGroundTruthSimulator
groundtruth_sim = MultiTargetGroundTruthSimulator(
    transition_model=transition_model,
    initial_state=initial_state,
    timestep=timestep_size,
    number_steps=number_of_steps,
    birth_rate=birth_rate,
    death_probability=death_probability
)

# %% [markdown]
# ### Initialise the measurement models
# The simulated ground truth will then be passed to a simple detection simulator. This again has a
# number of configurable parameters, e.g. where clutter is generated and at what rate, and
# detection probability. This implements similar logic to the code in the previous tutorial section
# `auto_tutorials/09_Initiators_&_Deleters:Generate Detections and Clutter`.

# %%
from stonesoup.simulator.simple import SimpleDetectionSimulator
from stonesoup.models.measurement.linear import LinearGaussian

# initialise the measurement model
measurement_model_covariance = np.diag([0.25, 0.25])
measurement_model = LinearGaussian(4, [0, 2], measurement_model_covariance)

# probability of detection
probability_detection = 0.9

# clutter will be generated uniformly in this are around the target
clutter_area = np.array([[-1, 1], [-1, 1]])*30
clutter_rate = 1

# %% [markdown]
# The detection simulator

# %%
detection_sim = SimpleDetectionSimulator(
    groundtruth=groundtruth_sim,
    measurement_model=measurement_model,
    detection_probability=probability_detection,
    meas_range=clutter_area,
    clutter_rate=clutter_rate
)

# %% [markdown]
# ## 2d lidar person detection test

# %%
# load logged file
# format: list of detections, each detctions is a nx3 numpy arra (detx,dety,detprob)

#filename = "/home/pblnav/logs/detections_11-19-2022-05-55-44.npz"
filename = "/home/pblnav/logs/detections_11-19-2022-05-56-29.npz"

data = np.load(filename)

person_detections = [data[k] for k in data]

for p in person_detections:
    #print(p)
    for d in p:
        print(d)
    break
# Out:
# [ 5.9869463  -2.61394129  0.99998772]
# [1.39674245 0.6150559  0.99980503]
# [ 5.79414298 -1.6730116   0.99971348]
# [ 6.63743661 -1.32559474  0.99288863]
# [ 0.35854218 -1.53810788  0.98771149]
# [-0.21337207  1.76440395  0.97714806]

# %% [markdown]
# ### Idea: wrap 2d lidar person detector detection in a stonesoup.detector.base.Detector

# %%
import threading
from abc import abstractmethod
from copy import copy
from datetime import timedelta

from stonesoup.detector.base import Detector
from stonesoup.base import Property
from stonesoup.buffered_generator import BufferedGenerator
from stonesoup.types.detection import Detection



class LidarPersonDetector(Detector):
    """ Stone Soup Detector wraper for 2d point detections (2d lidar person detector)
    Copied from Video Async Detector Abstract Class
   
    """
    
    person_detections: list = Property(
        doc="person_detections: generator or array of detections for each loop.  each Detection = Nx3 numpy (x,y,confidence)",
        default=False)

    def __init__(self,*args, **kwargs):
        super().__init__(None,*args, **kwargs)
        """
        Args:
            person_detections:
                generator or array of detections for each loop.  each Detection = Nx3 numpy (x,y,confidence)
        """ 
        self.person_detections = person_detections


    @BufferedGenerator.generator_method
    def detections_gen(self):
        """Returns a generator of detections for each frame.
        Yields
        ------
        : :class:`datetime.datetime`
            Datetime of current time step
        : set of :class:`~.Detection`
            Detections generated in the time step. The detection state vector is of the form
            ``(x, y)``, position of detection. Additionally, each detection carries the
            following meta-data fields:
            - ``confidence``: A float in the range ``(0, 1]`` indicating the detector's confidence
        """
        timestamp = datetime.datetime.now()
              
        for person_det in person_detections:
            
            detections = set()
            
            timestamp += timedelta(seconds=0.1)
            
            for det in person_det:
                
                state_vector = StateVector([det[0], det[1]])
                metadata = {"confidence": det[2]}
                
                detection = Detection(state_vector=state_vector, #StateVector
                                  timestamp=timestamp, #datetime.datetime
                                  metadata=metadata) #dictionary of metadata items
                detections.add(detection)
                
            
            yield timestamp, detections

# %%
detector = LidarPersonDetector(person_detections=person_detections)
for det in detector:
    print(det)
# Out:
# (datetime.datetime(2022, 11, 19, 18, 34, 55, 918096), {Detection(
#     state_vector=StateVector([[ 6.63743661],
#                               [-1.32559474]]),
#     timestamp=2022-11-19 18:34:55.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9928886294364929}), Detection(
#     state_vector=StateVector([[-0.21337207],
#                               [ 1.76440395]]),
#     timestamp=2022-11-19 18:34:55.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9771480560302734}), Detection(
#     state_vector=StateVector([[ 5.9869463 ],
#                               [-2.61394129]]),
#     timestamp=2022-11-19 18:34:55.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999877214431763}), Detection(
#     state_vector=StateVector([[1.39674245],
#                               [0.6150559 ]]),
#     timestamp=2022-11-19 18:34:55.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9998050332069397}), Detection(
#     state_vector=StateVector([[ 5.79414298],
#                               [-1.6730116 ]]),
#     timestamp=2022-11-19 18:34:55.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9997134804725647}), Detection(
#     state_vector=StateVector([[ 0.35854218],
#                               [-1.53810788]]),
#     timestamp=2022-11-19 18:34:55.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.987711489200592})})
# (datetime.datetime(2022, 11, 19, 18, 34, 56, 18096), {Detection(
#     state_vector=StateVector([[ 6.88416638],
#                               [-0.49398285]]),
#     timestamp=2022-11-19 18:34:56.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9235485196113586}), Detection(
#     state_vector=StateVector([[ 6.60015733],
#                               [-1.37915791]]),
#     timestamp=2022-11-19 18:34:56.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.995835542678833}), Detection(
#     state_vector=StateVector([[1.41327606],
#                               [0.61977533]]),
#     timestamp=2022-11-19 18:34:56.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9996423721313477}), Detection(
#     state_vector=StateVector([[ 5.794007 ],
#                               [-1.6708842]]),
#     timestamp=2022-11-19 18:34:56.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9995391368865967}), Detection(
#     state_vector=StateVector([[ 6.00544123],
#                               [-2.57837063]]),
#     timestamp=2022-11-19 18:34:56.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999737739562988}), Detection(
#     state_vector=StateVector([[ 0.76612326],
#                               [-1.73751327]]),
#     timestamp=2022-11-19 18:34:56.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9752219915390015}), Detection(
#     state_vector=StateVector([[-0.19718713],
#                               [ 1.79002323]]),
#     timestamp=2022-11-19 18:34:56.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9696341753005981})})
# (datetime.datetime(2022, 11, 19, 18, 34, 56, 118096), {Detection(
#     state_vector=StateVector([[ 5.80635266],
#                               [-1.68125684]]),
#     timestamp=2022-11-19 18:34:56.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9997639060020447}), Detection(
#     state_vector=StateVector([[ 6.59723851],
#                               [-1.38266263]]),
#     timestamp=2022-11-19 18:34:56.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.996509850025177}), Detection(
#     state_vector=StateVector([[ 0.79033131],
#                               [-1.73121093]]),
#     timestamp=2022-11-19 18:34:56.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9896149635314941}), Detection(
#     state_vector=StateVector([[-0.21375419],
#                               [ 1.74622647]]),
#     timestamp=2022-11-19 18:34:56.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9613281488418579}), Detection(
#     state_vector=StateVector([[ 5.98484286],
#                               [-2.55216188]]),
#     timestamp=2022-11-19 18:34:56.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999343156814575}), Detection(
#     state_vector=StateVector([[ 6.80261798],
#                               [-0.47890682]]),
#     timestamp=2022-11-19 18:34:56.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9705435633659363}), Detection(
#     state_vector=StateVector([[1.42663125],
#                               [0.62623719]]),
#     timestamp=2022-11-19 18:34:56.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9996548891067505})})
# (datetime.datetime(2022, 11, 19, 18, 34, 56, 218096), {Detection(
#     state_vector=StateVector([[ 0.73804736],
#                               [-1.7032349 ]]),
#     timestamp=2022-11-19 18:34:56.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9790228009223938}), Detection(
#     state_vector=StateVector([[1.44878867],
#                               [0.62602519]]),
#     timestamp=2022-11-19 18:34:56.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9997300505638123}), Detection(
#     state_vector=StateVector([[ 6.6119107 ],
#                               [-1.37569328]]),
#     timestamp=2022-11-19 18:34:56.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.997377872467041}), Detection(
#     state_vector=StateVector([[ 5.77915089],
#                               [-1.65840364]]),
#     timestamp=2022-11-19 18:34:56.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9991098046302795}), Detection(
#     state_vector=StateVector([[ 6.80058903],
#                               [-0.47403569]]),
#     timestamp=2022-11-19 18:34:56.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9834190607070923}), Detection(
#     state_vector=StateVector([[ 5.98366175],
#                               [-2.52915246]]),
#     timestamp=2022-11-19 18:34:56.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999094009399414}), Detection(
#     state_vector=StateVector([[-0.20120609],
#                               [ 1.756175  ]]),
#     timestamp=2022-11-19 18:34:56.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9132977724075317})})
# (datetime.datetime(2022, 11, 19, 18, 34, 56, 318096), {Detection(
#     state_vector=StateVector([[ 6.59569042],
#                               [-1.36201376]]),
#     timestamp=2022-11-19 18:34:56.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.99628084897995}), Detection(
#     state_vector=StateVector([[-0.2002278 ],
#                               [ 1.76747908]]),
#     timestamp=2022-11-19 18:34:56.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9486125111579895}), Detection(
#     state_vector=StateVector([[1.44408958],
#                               [0.61612286]]),
#     timestamp=2022-11-19 18:34:56.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9996507167816162}), Detection(
#     state_vector=StateVector([[ 6.81785436],
#                               [-0.53194724]]),
#     timestamp=2022-11-19 18:34:56.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9303944110870361}), Detection(
#     state_vector=StateVector([[ 5.97724346],
#                               [-2.56119111]]),
#     timestamp=2022-11-19 18:34:56.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999247789382935}), Detection(
#     state_vector=StateVector([[ 0.78605918],
#                               [-1.70142554]]),
#     timestamp=2022-11-19 18:34:56.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9653986692428589}), Detection(
#     state_vector=StateVector([[ 5.79152919],
#                               [-1.65922204]]),
#     timestamp=2022-11-19 18:34:56.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9981274008750916})})
# (datetime.datetime(2022, 11, 19, 18, 34, 56, 418096), {Detection(
#     state_vector=StateVector([[1.49276049],
#                               [0.60537551]]),
#     timestamp=2022-11-19 18:34:56.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.999754011631012}), Detection(
#     state_vector=StateVector([[ 6.72629858],
#                               [-0.50894634]]),
#     timestamp=2022-11-19 18:34:56.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9701085090637207}), Detection(
#     state_vector=StateVector([[ 0.76371087],
#                               [-1.71990137]]),
#     timestamp=2022-11-19 18:34:56.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.968845784664154}), Detection(
#     state_vector=StateVector([[-0.21622315],
#                               [ 1.75669863]]),
#     timestamp=2022-11-19 18:34:56.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9754806756973267}), Detection(
#     state_vector=StateVector([[2.20335353],
#                               [0.38109062]]),
#     timestamp=2022-11-19 18:34:56.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9249995350837708}), Detection(
#     state_vector=StateVector([[ 2.86004399],
#                               [-3.92152682]]),
#     timestamp=2022-11-19 18:34:56.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9401679635047913}), Detection(
#     state_vector=StateVector([[ 6.5810671 ],
#                               [-1.38942519]]),
#     timestamp=2022-11-19 18:34:56.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9980243444442749}), Detection(
#     state_vector=StateVector([[ 5.78207342],
#                               [-1.66176113]]),
#     timestamp=2022-11-19 18:34:56.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9977169036865234}), Detection(
#     state_vector=StateVector([[ 5.99209704],
#                               [-2.54540159]]),
#     timestamp=2022-11-19 18:34:56.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999409914016724})})
# (datetime.datetime(2022, 11, 19, 18, 34, 56, 518096), {Detection(
#     state_vector=StateVector([[ 5.76703866],
#                               [-1.67066395]]),
#     timestamp=2022-11-19 18:34:56.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9963666200637817}), Detection(
#     state_vector=StateVector([[ 6.74437165],
#                               [-0.50850591]]),
#     timestamp=2022-11-19 18:34:56.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9052765965461731}), Detection(
#     state_vector=StateVector([[ 0.39554341],
#                               [-1.56869969]]),
#     timestamp=2022-11-19 18:34:56.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9731507301330566}), Detection(
#     state_vector=StateVector([[ 6.01122015],
#                               [-2.57295708]]),
#     timestamp=2022-11-19 18:34:56.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999725818634033}), Detection(
#     state_vector=StateVector([[-0.2196949 ],
#                               [ 1.75781368]]),
#     timestamp=2022-11-19 18:34:56.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9695901274681091}), Detection(
#     state_vector=StateVector([[ 6.57523734],
#                               [-1.40868962]]),
#     timestamp=2022-11-19 18:34:56.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9990142583847046}), Detection(
#     state_vector=StateVector([[1.5224125 ],
#                               [0.56780543]]),
#     timestamp=2022-11-19 18:34:56.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999605417251587})})
# (datetime.datetime(2022, 11, 19, 18, 34, 56, 618096), {Detection(
#     state_vector=StateVector([[ 0.39398637],
#                               [-1.55231606]]),
#     timestamp=2022-11-19 18:34:56.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9817972183227539}), Detection(
#     state_vector=StateVector([[1.51973193],
#                               [0.55280292]]),
#     timestamp=2022-11-19 18:34:56.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999771118164062}), Detection(
#     state_vector=StateVector([[ 5.80799872],
#                               [-1.73526   ]]),
#     timestamp=2022-11-19 18:34:56.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9997455477714539}), Detection(
#     state_vector=StateVector([[-0.21262819],
#                               [ 1.761325  ]]),
#     timestamp=2022-11-19 18:34:56.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9263331294059753}), Detection(
#     state_vector=StateVector([[ 5.99138396],
#                               [-2.55950639]]),
#     timestamp=2022-11-19 18:34:56.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999445676803589}), Detection(
#     state_vector=StateVector([[ 6.73782542],
#                               [-0.48722465]]),
#     timestamp=2022-11-19 18:34:56.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.982317328453064}), Detection(
#     state_vector=StateVector([[ 6.57138971],
#                               [-1.40633274]]),
#     timestamp=2022-11-19 18:34:56.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.999079704284668})})
# (datetime.datetime(2022, 11, 19, 18, 34, 56, 718096), {Detection(
#     state_vector=StateVector([[-0.20896411],
#                               [ 1.76266635]]),
#     timestamp=2022-11-19 18:34:56.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9177817702293396}), Detection(
#     state_vector=StateVector([[ 0.46994169],
#                               [-1.57257677]]),
#     timestamp=2022-11-19 18:34:56.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9721460938453674}), Detection(
#     state_vector=StateVector([[ 5.76433531],
#                               [-1.72226178]]),
#     timestamp=2022-11-19 18:34:56.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9976809024810791}), Detection(
#     state_vector=StateVector([[ 5.97724922],
#                               [-2.53854732]]),
#     timestamp=2022-11-19 18:34:56.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.99993896484375}), Detection(
#     state_vector=StateVector([[ 6.58645599],
#                               [-1.3972813 ]]),
#     timestamp=2022-11-19 18:34:56.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9985589385032654}), Detection(
#     state_vector=StateVector([[1.58330189],
#                               [0.49766157]]),
#     timestamp=2022-11-19 18:34:56.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999140501022339})})
# (datetime.datetime(2022, 11, 19, 18, 34, 56, 818096), {Detection(
#     state_vector=StateVector([[ 0.75106445],
#                               [-1.68427003]]),
#     timestamp=2022-11-19 18:34:56.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9747540950775146}), Detection(
#     state_vector=StateVector([[ 6.57984432],
#                               [-1.38978492]]),
#     timestamp=2022-11-19 18:34:56.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9979726672172546}), Detection(
#     state_vector=StateVector([[ 5.99270435],
#                               [-2.53553769]]),
#     timestamp=2022-11-19 18:34:56.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999196529388428}), Detection(
#     state_vector=StateVector([[ 5.79607956],
#                               [-1.68525587]]),
#     timestamp=2022-11-19 18:34:56.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9982286095619202}), Detection(
#     state_vector=StateVector([[ 6.7269451 ],
#                               [-0.45370463]]),
#     timestamp=2022-11-19 18:34:56.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9852141737937927}), Detection(
#     state_vector=StateVector([[1.58691234],
#                               [0.3305867 ]]),
#     timestamp=2022-11-19 18:34:56.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999663829803467})})
# (datetime.datetime(2022, 11, 19, 18, 34, 56, 918096), {Detection(
#     state_vector=StateVector([[ 5.78502481],
#                               [-1.6749819 ]]),
#     timestamp=2022-11-19 18:34:56.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9976149797439575}), Detection(
#     state_vector=StateVector([[ 5.98303908],
#                               [-2.56812623]]),
#     timestamp=2022-11-19 18:34:56.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.999972939491272}), Detection(
#     state_vector=StateVector([[ 0.70919963],
#                               [-1.66339484]]),
#     timestamp=2022-11-19 18:34:56.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9847069382667542}), Detection(
#     state_vector=StateVector([[1.5582729 ],
#                               [0.19614442]]),
#     timestamp=2022-11-19 18:34:56.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999879598617554}), Detection(
#     state_vector=StateVector([[-0.2154719 ],
#                               [ 1.76372876]]),
#     timestamp=2022-11-19 18:34:56.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.917043924331665}), Detection(
#     state_vector=StateVector([[ 6.59324538],
#                               [-1.40044195]]),
#     timestamp=2022-11-19 18:34:56.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9980521202087402})})
# (datetime.datetime(2022, 11, 19, 18, 34, 57, 18096), {Detection(
#     state_vector=StateVector([[1.68008295],
#                               [0.28494109]]),
#     timestamp=2022-11-19 18:34:57.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999425411224365}), Detection(
#     state_vector=StateVector([[-0.20150264],
#                               [ 1.78402636]]),
#     timestamp=2022-11-19 18:34:57.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9613989591598511}), Detection(
#     state_vector=StateVector([[6.86615268],
#                               [0.57470599]]),
#     timestamp=2022-11-19 18:34:57.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9800997376441956}), Detection(
#     state_vector=StateVector([[ 5.78341805],
#                               [-1.64993987]]),
#     timestamp=2022-11-19 18:34:57.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9977713823318481}), Detection(
#     state_vector=StateVector([[ 6.58511012],
#                               [-1.41073536]]),
#     timestamp=2022-11-19 18:34:57.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9986470341682434}), Detection(
#     state_vector=StateVector([[ 0.74189012],
#                               [-1.66537757]]),
#     timestamp=2022-11-19 18:34:57.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9810417890548706}), Detection(
#     state_vector=StateVector([[ 6.00243423],
#                               [-2.57377776]]),
#     timestamp=2022-11-19 18:34:57.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999570846557617})})
# (datetime.datetime(2022, 11, 19, 18, 34, 57, 118096), {Detection(
#     state_vector=StateVector([[ 6.51551937],
#                               [-1.41990775]]),
#     timestamp=2022-11-19 18:34:57.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9974203109741211}), Detection(
#     state_vector=StateVector([[-0.21174875],
#                               [ 1.77152646]]),
#     timestamp=2022-11-19 18:34:57.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9521270990371704}), Detection(
#     state_vector=StateVector([[2.10162094],
#                               [0.39794503]]),
#     timestamp=2022-11-19 18:34:57.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9769423007965088}), Detection(
#     state_vector=StateVector([[ 1.4914373 ],
#                               [-0.00417176]]),
#     timestamp=2022-11-19 18:34:57.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999725818634033}), Detection(
#     state_vector=StateVector([[ 6.83718882],
#                               [-0.23829816]]),
#     timestamp=2022-11-19 18:34:57.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9294266700744629}), Detection(
#     state_vector=StateVector([[ 5.78930067],
#                               [-1.64977469]]),
#     timestamp=2022-11-19 18:34:57.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9981855750083923}), Detection(
#     state_vector=StateVector([[ 5.98152921],
#                               [-2.552967  ]]),
#     timestamp=2022-11-19 18:34:57.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999485015869141}), Detection(
#     state_vector=StateVector([[ 0.81717665],
#                               [-1.75842641]]),
#     timestamp=2022-11-19 18:34:57.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9627758264541626})})
# (datetime.datetime(2022, 11, 19, 18, 34, 57, 218096), {Detection(
#     state_vector=StateVector([[ 5.98546336],
#                               [-2.54740476]]),
#     timestamp=2022-11-19 18:34:57.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999324083328247}), Detection(
#     state_vector=StateVector([[ 1.48715747],
#                               [-0.09086686]]),
#     timestamp=2022-11-19 18:34:57.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.999991774559021}), Detection(
#     state_vector=StateVector([[-0.21056858],
#                               [ 1.77065667]]),
#     timestamp=2022-11-19 18:34:57.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9654645919799805}), Detection(
#     state_vector=StateVector([[ 6.7898045 ],
#                               [-0.41694238]]),
#     timestamp=2022-11-19 18:34:57.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9465209245681763}), Detection(
#     state_vector=StateVector([[ 5.79035641],
#                               [-1.65316409]]),
#     timestamp=2022-11-19 18:34:57.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9958422780036926}), Detection(
#     state_vector=StateVector([[ 0.77508675],
#                               [-1.68212486]]),
#     timestamp=2022-11-19 18:34:57.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9689638614654541})})
# (datetime.datetime(2022, 11, 19, 18, 34, 57, 318096), {Detection(
#     state_vector=StateVector([[ 1.54446424],
#                               [-0.11394837]]),
#     timestamp=2022-11-19 18:34:57.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999880790710449}), Detection(
#     state_vector=StateVector([[ 6.01276318],
#                               [-2.57260646]]),
#     timestamp=2022-11-19 18:34:57.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999657869338989}), Detection(
#     state_vector=StateVector([[ 5.777458  ],
#                               [-1.67125538]]),
#     timestamp=2022-11-19 18:34:57.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9966098666191101}), Detection(
#     state_vector=StateVector([[-0.20976986],
#                               [ 1.77489665]]),
#     timestamp=2022-11-19 18:34:57.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9834769368171692})})
# (datetime.datetime(2022, 11, 19, 18, 34, 57, 418096), {Detection(
#     state_vector=StateVector([[2.20348822],
#                               [0.33576941]]),
#     timestamp=2022-11-19 18:34:57.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9401142001152039}), Detection(
#     state_vector=StateVector([[ 6.71017043],
#                               [-0.14868861]]),
#     timestamp=2022-11-19 18:34:57.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9601544141769409}), Detection(
#     state_vector=StateVector([[ 5.99469687],
#                               [-2.57985538]]),
#     timestamp=2022-11-19 18:34:57.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999188184738159}), Detection(
#     state_vector=StateVector([[ 0.42926282],
#                               [-1.57536027]]),
#     timestamp=2022-11-19 18:34:57.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9666175842285156}), Detection(
#     state_vector=StateVector([[ 6.69115417],
#                               [-0.79380989]]),
#     timestamp=2022-11-19 18:34:57.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9985805749893188}), Detection(
#     state_vector=StateVector([[ 1.46403944],
#                               [-0.40459336]]),
#     timestamp=2022-11-19 18:34:57.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999380111694336}), Detection(
#     state_vector=StateVector([[-0.20625426],
#                               [ 1.78087245]]),
#     timestamp=2022-11-19 18:34:57.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9486794471740723}), Detection(
#     state_vector=StateVector([[3.18684971],
#                               [0.99634902]]),
#     timestamp=2022-11-19 18:34:57.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9827175736427307})})
# (datetime.datetime(2022, 11, 19, 18, 34, 57, 518096), {Detection(
#     state_vector=StateVector([[ 0.45666739],
#                               [-1.58199034]]),
#     timestamp=2022-11-19 18:34:57.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9641302227973938}), Detection(
#     state_vector=StateVector([[ 6.54508671],
#                               [-1.3937357 ]]),
#     timestamp=2022-11-19 18:34:57.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9963217973709106}), Detection(
#     state_vector=StateVector([[ 6.67772857],
#                               [-0.90407442]]),
#     timestamp=2022-11-19 18:34:57.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9818863868713379}), Detection(
#     state_vector=StateVector([[ 1.4020233 ],
#                               [-0.56269358]]),
#     timestamp=2022-11-19 18:34:57.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9998977184295654}), Detection(
#     state_vector=StateVector([[3.19785865],
#                               [0.99264656]]),
#     timestamp=2022-11-19 18:34:57.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9877718687057495})})
# (datetime.datetime(2022, 11, 19, 18, 34, 57, 618096), {Detection(
#     state_vector=StateVector([[ 1.44669975],
#                               [-0.55432478]]),
#     timestamp=2022-11-19 18:34:57.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999709129333496}), Detection(
#     state_vector=StateVector([[ 0.89630883],
#                               [-1.77522211]]),
#     timestamp=2022-11-19 18:34:57.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.969714343547821}), Detection(
#     state_vector=StateVector([[3.19604976],
#                               [0.97656281]]),
#     timestamp=2022-11-19 18:34:57.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9795897603034973}), Detection(
#     state_vector=StateVector([[ 0.40678361],
#                               [-1.54494004]]),
#     timestamp=2022-11-19 18:34:57.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9822725057601929}), Detection(
#     state_vector=StateVector([[ 6.57806707],
#                               [-1.43540142]]),
#     timestamp=2022-11-19 18:34:57.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.994644284248352}), Detection(
#     state_vector=StateVector([[-0.19911863],
#                               [ 1.76017562]]),
#     timestamp=2022-11-19 18:34:57.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9141168594360352})})
# (datetime.datetime(2022, 11, 19, 18, 34, 57, 718096), {Detection(
#     state_vector=StateVector([[ 6.60741784],
#                               [-1.39370729]]),
#     timestamp=2022-11-19 18:34:57.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9929704070091248}), Detection(
#     state_vector=StateVector([[ 0.39613911],
#                               [-1.56895458]]),
#     timestamp=2022-11-19 18:34:57.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9737268090248108}), Detection(
#     state_vector=StateVector([[3.19244939],
#                               [1.02095764]]),
#     timestamp=2022-11-19 18:34:57.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9912574291229248}), Detection(
#     state_vector=StateVector([[-0.19237723],
#                               [ 1.76476994]]),
#     timestamp=2022-11-19 18:34:57.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9750710129737854}), Detection(
#     state_vector=StateVector([[ 1.39126419],
#                               [-0.53876342]]),
#     timestamp=2022-11-19 18:34:57.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999872446060181}), Detection(
#     state_vector=StateVector([[ 5.97486412],
#                               [-2.48674202]]),
#     timestamp=2022-11-19 18:34:57.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.928180456161499})})
# (datetime.datetime(2022, 11, 19, 18, 34, 57, 818096), {Detection(
#     state_vector=StateVector([[-0.19400884],
#                               [ 1.75247686]]),
#     timestamp=2022-11-19 18:34:57.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9662358164787292}), Detection(
#     state_vector=StateVector([[ 5.772896  ],
#                               [-1.74333072]]),
#     timestamp=2022-11-19 18:34:57.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.943108856678009}), Detection(
#     state_vector=StateVector([[3.19765386],
#                               [0.9848258 ]]),
#     timestamp=2022-11-19 18:34:57.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9020926356315613}), Detection(
#     state_vector=StateVector([[ 0.42714718],
#                               [-1.56478021]]),
#     timestamp=2022-11-19 18:34:57.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9306282997131348}), Detection(
#     state_vector=StateVector([[ 1.41147995],
#                               [-0.46822922]]),
#     timestamp=2022-11-19 18:34:57.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999920129776001})})
# (datetime.datetime(2022, 11, 19, 18, 34, 57, 918096), {Detection(
#     state_vector=StateVector([[ 6.64818554],
#                               [-1.35663857]]),
#     timestamp=2022-11-19 18:34:57.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9991556406021118}), Detection(
#     state_vector=StateVector([[ 0.39317457],
#                               [-1.54810271]]),
#     timestamp=2022-11-19 18:34:57.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.951188325881958}), Detection(
#     state_vector=StateVector([[-0.19664387],
#                               [ 1.75477285]]),
#     timestamp=2022-11-19 18:34:57.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9307488799095154}), Detection(
#     state_vector=StateVector([[3.16750785],
#                               [0.99267759]]),
#     timestamp=2022-11-19 18:34:57.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.984603226184845}), Detection(
#     state_vector=StateVector([[ 5.78689458],
#                               [-1.73889524]]),
#     timestamp=2022-11-19 18:34:57.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9763694405555725}), Detection(
#     state_vector=StateVector([[ 1.42478087],
#                               [-0.34986835]]),
#     timestamp=2022-11-19 18:34:57.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9996596574783325})})
# (datetime.datetime(2022, 11, 19, 18, 34, 58, 18096), {Detection(
#     state_vector=StateVector([[3.18392658],
#                               [0.977116  ]]),
#     timestamp=2022-11-19 18:34:58.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9892929792404175}), Detection(
#     state_vector=StateVector([[ 1.36036921],
#                               [-0.2753454 ]]),
#     timestamp=2022-11-19 18:34:58.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999780654907227}), Detection(
#     state_vector=StateVector([[ 6.59892572],
#                               [-1.40807394]]),
#     timestamp=2022-11-19 18:34:58.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9979562759399414}), Detection(
#     state_vector=StateVector([[-0.18745751],
#                               [ 1.76612093]]),
#     timestamp=2022-11-19 18:34:58.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9186122417449951}), Detection(
#     state_vector=StateVector([[ 6.1436174 ],
#                               [-2.84030017]]),
#     timestamp=2022-11-19 18:34:58.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.99522864818573}), Detection(
#     state_vector=StateVector([[ 0.44425007],
#                               [-1.48824442]]),
#     timestamp=2022-11-19 18:34:58.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9605352878570557})})
# (datetime.datetime(2022, 11, 19, 18, 34, 58, 118096), {Detection(
#     state_vector=StateVector([[3.14440555],
#                               [0.98946617]]),
#     timestamp=2022-11-19 18:34:58.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9787992238998413}), Detection(
#     state_vector=StateVector([[ 6.51705001],
#                               [-1.33479374]]),
#     timestamp=2022-11-19 18:34:58.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9453416466712952}), Detection(
#     state_vector=StateVector([[ 5.78790664],
#                               [-3.26680984]]),
#     timestamp=2022-11-19 18:34:58.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9310786724090576}), Detection(
#     state_vector=StateVector([[ 6.0916505 ],
#                               [-2.74798232]]),
#     timestamp=2022-11-19 18:34:58.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9997560381889343}), Detection(
#     state_vector=StateVector([[ 5.80634373],
#                               [-1.75384843]]),
#     timestamp=2022-11-19 18:34:58.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9258897304534912}), Detection(
#     state_vector=StateVector([[ 1.37772259],
#                               [-0.16591205]]),
#     timestamp=2022-11-19 18:34:58.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999310970306396}), Detection(
#     state_vector=StateVector([[-0.20124127],
#                               [ 1.76466632]]),
#     timestamp=2022-11-19 18:34:58.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9466177821159363})})
# (datetime.datetime(2022, 11, 19, 18, 34, 58, 218096), {Detection(
#     state_vector=StateVector([[1.39825843],
#                               [0.00188825]]),
#     timestamp=2022-11-19 18:34:58.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999939203262329}), Detection(
#     state_vector=StateVector([[ 6.5739827 ],
#                               [-1.35625425]]),
#     timestamp=2022-11-19 18:34:58.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9802418947219849}), Detection(
#     state_vector=StateVector([[-0.19938159],
#                               [ 1.75482235]]),
#     timestamp=2022-11-19 18:34:58.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9643837213516235}), Detection(
#     state_vector=StateVector([[ 0.73110362],
#                               [-1.68881445]]),
#     timestamp=2022-11-19 18:34:58.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9513807892799377}), Detection(
#     state_vector=StateVector([[ 5.80438518],
#                               [-3.26141431]]),
#     timestamp=2022-11-19 18:34:58.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9141864776611328}), Detection(
#     state_vector=StateVector([[3.16406816],
#                               [0.9719091 ]]),
#     timestamp=2022-11-19 18:34:58.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9884927868843079}), Detection(
#     state_vector=StateVector([[ 6.70698204],
#                               [-0.83895898]]),
#     timestamp=2022-11-19 18:34:58.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9663121700286865}), Detection(
#     state_vector=StateVector([[ 6.06533119],
#                               [-2.72273896]]),
#     timestamp=2022-11-19 18:34:58.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9998388290405273}), Detection(
#     state_vector=StateVector([[ 5.76859172],
#                               [-1.71527812]]),
#     timestamp=2022-11-19 18:34:58.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9738627076148987})})
# (datetime.datetime(2022, 11, 19, 18, 34, 58, 318096), {Detection(
#     state_vector=StateVector([[1.41928304],
#                               [0.11798776]]),
#     timestamp=2022-11-19 18:34:58.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999816417694092}), Detection(
#     state_vector=StateVector([[ 6.62837163],
#                               [-1.33797637]]),
#     timestamp=2022-11-19 18:34:58.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.992348313331604}), Detection(
#     state_vector=StateVector([[-0.21555089],
#                               [ 1.75540678]]),
#     timestamp=2022-11-19 18:34:58.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9633318781852722}), Detection(
#     state_vector=StateVector([[ 5.97456669],
#                               [-2.60444671]]),
#     timestamp=2022-11-19 18:34:58.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999021291732788}), Detection(
#     state_vector=StateVector([[3.17982718],
#                               [1.02296236]]),
#     timestamp=2022-11-19 18:34:58.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9558477997779846}), Detection(
#     state_vector=StateVector([[ 0.68781936],
#                               [-1.72170095]]),
#     timestamp=2022-11-19 18:34:58.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9571436643600464}), Detection(
#     state_vector=StateVector([[ 5.80471344],
#                               [-1.70056281]]),
#     timestamp=2022-11-19 18:34:58.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9959198236465454})})
# (datetime.datetime(2022, 11, 19, 18, 34, 58, 418096), {Detection(
#     state_vector=StateVector([[ 6.61216991],
#                               [-1.37138177]]),
#     timestamp=2022-11-19 18:34:58.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9945061802864075}), Detection(
#     state_vector=StateVector([[ 6.78299519],
#                               [-0.50920755]]),
#     timestamp=2022-11-19 18:34:58.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9988564252853394}), Detection(
#     state_vector=StateVector([[3.22053491],
#                               [0.99060231]]),
#     timestamp=2022-11-19 18:34:58.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9136890172958374}), Detection(
#     state_vector=StateVector([[-0.18506968],
#                               [ 1.77851132]]),
#     timestamp=2022-11-19 18:34:58.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9526481628417969}), Detection(
#     state_vector=StateVector([[ 5.97020153],
#                               [-2.57531831]]),
#     timestamp=2022-11-19 18:34:58.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999301433563232}), Detection(
#     state_vector=StateVector([[ 0.33462354],
#                               [-1.5235336 ]]),
#     timestamp=2022-11-19 18:34:58.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9970284104347229}), Detection(
#     state_vector=StateVector([[1.40133976],
#                               [0.14531236]]),
#     timestamp=2022-11-19 18:34:58.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999738931655884}), Detection(
#     state_vector=StateVector([[ 5.79096167],
#                               [-1.68071206]]),
#     timestamp=2022-11-19 18:34:58.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9972782731056213})})
# (datetime.datetime(2022, 11, 19, 18, 34, 58, 518096), {Detection(
#     state_vector=StateVector([[ 5.7783399 ],
#                               [-1.69379779]]),
#     timestamp=2022-11-19 18:34:58.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9981769323348999}), Detection(
#     state_vector=StateVector([[ 0.42434083],
#                               [-1.5318905 ]]),
#     timestamp=2022-11-19 18:34:58.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.99378502368927}), Detection(
#     state_vector=StateVector([[ 6.59833421],
#                               [-1.33713134]]),
#     timestamp=2022-11-19 18:34:58.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9919387698173523}), Detection(
#     state_vector=StateVector([[-0.20388763],
#                               [ 1.76854049]]),
#     timestamp=2022-11-19 18:34:58.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9241450428962708}), Detection(
#     state_vector=StateVector([[1.41242713],
#                               [0.11553166]]),
#     timestamp=2022-11-19 18:34:58.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999837875366211}), Detection(
#     state_vector=StateVector([[ 5.97758489],
#                               [-2.56525705]]),
#     timestamp=2022-11-19 18:34:58.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999548196792603})})
# (datetime.datetime(2022, 11, 19, 18, 34, 58, 618096), {Detection(
#     state_vector=StateVector([[ 5.77998896],
#                               [-1.67236214]]),
#     timestamp=2022-11-19 18:34:58.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9987049102783203}), Detection(
#     state_vector=StateVector([[ 0.38602762],
#                               [-1.54993326]]),
#     timestamp=2022-11-19 18:34:58.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9499966502189636}), Detection(
#     state_vector=StateVector([[ 6.00089306],
#                               [-2.55712953]]),
#     timestamp=2022-11-19 18:34:58.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999517202377319}), Detection(
#     state_vector=StateVector([[6.8613881 ],
#                               [0.56773388]]),
#     timestamp=2022-11-19 18:34:58.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.973246693611145}), Detection(
#     state_vector=StateVector([[-0.17950975],
#                               [ 1.78173885]]),
#     timestamp=2022-11-19 18:34:58.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9085842967033386}), Detection(
#     state_vector=StateVector([[ 6.6182369 ],
#                               [-1.36369952]]),
#     timestamp=2022-11-19 18:34:58.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9971083998680115}), Detection(
#     state_vector=StateVector([[1.49696681],
#                               [0.08060847]]),
#     timestamp=2022-11-19 18:34:58.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999957084655762})})
# (datetime.datetime(2022, 11, 19, 18, 34, 58, 718096), {Detection(
#     state_vector=StateVector([[ 6.54497571],
#                               [-1.40239082]]),
#     timestamp=2022-11-19 18:34:58.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.997745931148529}), Detection(
#     state_vector=StateVector([[1.55522543],
#                               [0.03371189]]),
#     timestamp=2022-11-19 18:34:58.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999938011169434}), Detection(
#     state_vector=StateVector([[-0.17745813],
#                               [ 1.77527095]]),
#     timestamp=2022-11-19 18:34:58.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9305696487426758}), Detection(
#     state_vector=StateVector([[3.27003767],
#                               [1.05121419]]),
#     timestamp=2022-11-19 18:34:58.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9033123850822449}), Detection(
#     state_vector=StateVector([[ 6.00169198],
#                               [-2.54915679]]),
#     timestamp=2022-11-19 18:34:58.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999486207962036}), Detection(
#     state_vector=StateVector([[ 0.45742016],
#                               [-1.5270723 ]]),
#     timestamp=2022-11-19 18:34:58.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.955168604850769}), Detection(
#     state_vector=StateVector([[ 6.82769313],
#                               [-0.47876741]]),
#     timestamp=2022-11-19 18:34:58.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9939233660697937}), Detection(
#     state_vector=StateVector([[ 5.79109582],
#                               [-1.66849718]]),
#     timestamp=2022-11-19 18:34:58.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9984702467918396})})
# (datetime.datetime(2022, 11, 19, 18, 34, 58, 818096), {Detection(
#     state_vector=StateVector([[ 5.81424268],
#                               [-1.64907851]]),
#     timestamp=2022-11-19 18:34:58.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.998649537563324}), Detection(
#     state_vector=StateVector([[-0.19917698],
#                               [ 1.75804191]]),
#     timestamp=2022-11-19 18:34:58.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9639778733253479}), Detection(
#     state_vector=StateVector([[ 6.54020446],
#                               [-1.38940024]]),
#     timestamp=2022-11-19 18:34:58.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9190643429756165}), Detection(
#     state_vector=StateVector([[ 0.46359572],
#                               [-1.51288193]]),
#     timestamp=2022-11-19 18:34:58.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9275791049003601}), Detection(
#     state_vector=StateVector([[ 6.78255978],
#                               [-0.48412304]]),
#     timestamp=2022-11-19 18:34:58.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9823868274688721}), Detection(
#     state_vector=StateVector([[3.20162401],
#                               [1.03712757]]),
#     timestamp=2022-11-19 18:34:58.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9479127526283264}), Detection(
#     state_vector=StateVector([[ 5.98412851],
#                               [-2.54334628]]),
#     timestamp=2022-11-19 18:34:58.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999545812606812}), Detection(
#     state_vector=StateVector([[ 1.6465428],
#                               [-0.0619433]]),
#     timestamp=2022-11-19 18:34:58.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999922513961792})})
# (datetime.datetime(2022, 11, 19, 18, 34, 58, 918096), {Detection(
#     state_vector=StateVector([[ 6.05515583],
#                               [-2.59004503]]),
#     timestamp=2022-11-19 18:34:58.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999806880950928}), Detection(
#     state_vector=StateVector([[ 0.44279985],
#                               [-1.54245716]]),
#     timestamp=2022-11-19 18:34:58.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9804613590240479}), Detection(
#     state_vector=StateVector([[6.84219357],
#                               [0.61851702]]),
#     timestamp=2022-11-19 18:34:58.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9845715761184692}), Detection(
#     state_vector=StateVector([[ 1.85338549],
#                               [-0.19582087]]),
#     timestamp=2022-11-19 18:34:58.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9997602105140686}), Detection(
#     state_vector=StateVector([[3.20001473],
#                               [1.02670486]]),
#     timestamp=2022-11-19 18:34:58.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.965369701385498}), Detection(
#     state_vector=StateVector([[-0.17946708],
#                               [ 1.78095446]]),
#     timestamp=2022-11-19 18:34:58.918096,
#     measurement_model=None,
# ...
#     measurement_model=None,
#     metadata={'confidence': 0.9999654293060303}), Detection(
#     state_vector=StateVector([[3.25684525],
#                               [1.00337399]]),
#     timestamp=2022-11-19 18:35:12.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9717065095901489}), Detection(
#     state_vector=StateVector([[ 6.59351583],
#                               [-1.35925031]]),
#     timestamp=2022-11-19 18:35:12.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9972213506698608}), Detection(
#     state_vector=StateVector([[ 6.76424867],
#                               [-0.5125984 ]]),
#     timestamp=2022-11-19 18:35:12.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9907547831535339}), Detection(
#     state_vector=StateVector([[-1.99840748],
#                               [-2.79848769]]),
#     timestamp=2022-11-19 18:35:12.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9564648270606995}), Detection(
#     state_vector=StateVector([[ 0.30417109],
#                               [-0.67710747]]),
#     timestamp=2022-11-19 18:35:12.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9979544878005981}), Detection(
#     state_vector=StateVector([[ 5.79837287],
#                               [-1.6372066 ]]),
#     timestamp=2022-11-19 18:35:12.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9971724152565002})})
# (datetime.datetime(2022, 11, 19, 18, 35, 12, 418096), {Detection(
#     state_vector=StateVector([[ 0.93561207],
#                               [-0.41348462]]),
#     timestamp=2022-11-19 18:35:12.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9471467733383179}), Detection(
#     state_vector=StateVector([[ 5.79593648],
#                               [-1.70019715]]),
#     timestamp=2022-11-19 18:35:12.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9982430934906006}), Detection(
#     state_vector=StateVector([[3.23360625],
#                               [0.98851232]]),
#     timestamp=2022-11-19 18:35:12.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9313775300979614}), Detection(
#     state_vector=StateVector([[ 6.57599324],
#                               [-1.39929931]]),
#     timestamp=2022-11-19 18:35:12.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9986973404884338}), Detection(
#     state_vector=StateVector([[-0.17716305],
#                               [ 1.77941782]]),
#     timestamp=2022-11-19 18:35:12.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9266447424888611}), Detection(
#     state_vector=StateVector([[ 0.32088089],
#                               [-1.58664769]]),
#     timestamp=2022-11-19 18:35:12.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9858942031860352}), Detection(
#     state_vector=StateVector([[ 6.76663562],
#                               [-0.48448051]]),
#     timestamp=2022-11-19 18:35:12.418096,
#     measurement_model=None,
#     metadata={'confidence': 0.9861369132995605})})
# (datetime.datetime(2022, 11, 19, 18, 35, 12, 518096), {Detection(
#     state_vector=StateVector([[ 0.94815387],
#                               [-0.09789464]]),
#     timestamp=2022-11-19 18:35:12.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9971537590026855}), Detection(
#     state_vector=StateVector([[ 5.79488597],
#                               [-1.68113109]]),
#     timestamp=2022-11-19 18:35:12.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.992197573184967}), Detection(
#     state_vector=StateVector([[-0.18262781],
#                               [ 1.76813093]]),
#     timestamp=2022-11-19 18:35:12.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9514346122741699}), Detection(
#     state_vector=StateVector([[ 0.26679835],
#                               [-1.58444899]]),
#     timestamp=2022-11-19 18:35:12.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.981891930103302}), Detection(
#     state_vector=StateVector([[ 6.08375871],
#                               [-2.75586439]]),
#     timestamp=2022-11-19 18:35:12.518096,
#     measurement_model=None,
#     metadata={'confidence': 0.9987998008728027})})
# (datetime.datetime(2022, 11, 19, 18, 35, 12, 618096), {Detection(
#     state_vector=StateVector([[1.35489465],
#                               [0.47788455]]),
#     timestamp=2022-11-19 18:35:12.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9685705304145813}), Detection(
#     state_vector=StateVector([[-0.21037824],
#                               [ 1.76081719]]),
#     timestamp=2022-11-19 18:35:12.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9431419372558594}), Detection(
#     state_vector=StateVector([[ 0.77201213],
#                               [-1.8091375 ]]),
#     timestamp=2022-11-19 18:35:12.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9336426258087158}), Detection(
#     state_vector=StateVector([[ 6.1000772 ],
#                               [-2.71932496]]),
#     timestamp=2022-11-19 18:35:12.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9997684359550476}), Detection(
#     state_vector=StateVector([[ 5.81198271],
#                               [-1.73286193]]),
#     timestamp=2022-11-19 18:35:12.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.9991773962974548}), Detection(
#     state_vector=StateVector([[ 1.1879807 ],
#                               [-0.17737067]]),
#     timestamp=2022-11-19 18:35:12.618096,
#     measurement_model=None,
#     metadata={'confidence': 0.995870053768158})})
# (datetime.datetime(2022, 11, 19, 18, 35, 12, 718096), {Detection(
#     state_vector=StateVector([[ 5.98958267],
#                               [-2.52732036]]),
#     timestamp=2022-11-19 18:35:12.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9998533725738525}), Detection(
#     state_vector=StateVector([[ 6.43196567],
#                               [-1.3793246 ]]),
#     timestamp=2022-11-19 18:35:12.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9646260142326355}), Detection(
#     state_vector=StateVector([[1.38596253],
#                               [0.52513163]]),
#     timestamp=2022-11-19 18:35:12.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9986847043037415}), Detection(
#     state_vector=StateVector([[ 5.82598232],
#                               [-1.71199401]]),
#     timestamp=2022-11-19 18:35:12.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9996870756149292}), Detection(
#     state_vector=StateVector([[ 6.66132078],
#                               [-0.83671348]]),
#     timestamp=2022-11-19 18:35:12.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9974615573883057}), Detection(
#     state_vector=StateVector([[-0.20467304],
#                               [ 1.77287202]]),
#     timestamp=2022-11-19 18:35:12.718096,
#     measurement_model=None,
#     metadata={'confidence': 0.9525885581970215})})
# (datetime.datetime(2022, 11, 19, 18, 35, 12, 818096), {Detection(
#     state_vector=StateVector([[ 6.02974163],
#                               [-2.58185711]]),
#     timestamp=2022-11-19 18:35:12.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999567270278931}), Detection(
#     state_vector=StateVector([[ 0.67862262],
#                               [-1.69139684]]),
#     timestamp=2022-11-19 18:35:12.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9533792734146118}), Detection(
#     state_vector=StateVector([[-0.19284828],
#                               [ 1.78321172]]),
#     timestamp=2022-11-19 18:35:12.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9103591442108154}), Detection(
#     state_vector=StateVector([[ 6.61526044],
#                               [-1.2236895 ]]),
#     timestamp=2022-11-19 18:35:12.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9918374419212341}), Detection(
#     state_vector=StateVector([[ 5.81257965],
#                               [-1.70373068]]),
#     timestamp=2022-11-19 18:35:12.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9997902512550354}), Detection(
#     state_vector=StateVector([[1.4456507 ],
#                               [0.64257926]]),
#     timestamp=2022-11-19 18:35:12.818096,
#     measurement_model=None,
#     metadata={'confidence': 0.9960387945175171})})
# (datetime.datetime(2022, 11, 19, 18, 35, 12, 918096), {Detection(
#     state_vector=StateVector([[ 6.00100148],
#                               [-2.55871562]]),
#     timestamp=2022-11-19 18:35:12.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.999951958656311}), Detection(
#     state_vector=StateVector([[-0.19607593],
#                               [ 1.76793893]]),
#     timestamp=2022-11-19 18:35:12.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9571442008018494}), Detection(
#     state_vector=StateVector([[1.50293234],
#                               [0.69099389]]),
#     timestamp=2022-11-19 18:35:12.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9998051524162292}), Detection(
#     state_vector=StateVector([[ 6.60921686],
#                               [-1.31347493]]),
#     timestamp=2022-11-19 18:35:12.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9950272440910339}), Detection(
#     state_vector=StateVector([[ 5.82863803],
#                               [-1.70139668]]),
#     timestamp=2022-11-19 18:35:12.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9998502731323242}), Detection(
#     state_vector=StateVector([[ 6.75610556],
#                               [-0.4954379 ]]),
#     timestamp=2022-11-19 18:35:12.918096,
#     measurement_model=None,
#     metadata={'confidence': 0.9567063450813293})})
# (datetime.datetime(2022, 11, 19, 18, 35, 13, 18096), {Detection(
#     state_vector=StateVector([[ 0.76454519],
#                               [-1.57785193]]),
#     timestamp=2022-11-19 18:35:13.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9650121331214905}), Detection(
#     state_vector=StateVector([[ 5.82168341],
#                               [-1.72312212]]),
#     timestamp=2022-11-19 18:35:13.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999258518218994}), Detection(
#     state_vector=StateVector([[1.50133331],
#                               [0.65706307]]),
#     timestamp=2022-11-19 18:35:13.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999364614486694}), Detection(
#     state_vector=StateVector([[-0.19867921],
#                               [ 1.75971046]]),
#     timestamp=2022-11-19 18:35:13.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9373282790184021}), Detection(
#     state_vector=StateVector([[ 6.75025937],
#                               [-0.45576259]]),
#     timestamp=2022-11-19 18:35:13.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9514614343643188}), Detection(
#     state_vector=StateVector([[ 5.98064068],
#                               [-2.56497568]]),
#     timestamp=2022-11-19 18:35:13.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.999937891960144}), Detection(
#     state_vector=StateVector([[ 6.60586938],
#                               [-1.40526935]]),
#     timestamp=2022-11-19 18:35:13.018096,
#     measurement_model=None,
#     metadata={'confidence': 0.9956757426261902})})
# (datetime.datetime(2022, 11, 19, 18, 35, 13, 118096), {Detection(
#     state_vector=StateVector([[ 6.60231138],
#                               [-1.37301397]]),
#     timestamp=2022-11-19 18:35:13.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9965699911117554}), Detection(
#     state_vector=StateVector([[-0.20444281],
#                               [ 1.7504144 ]]),
#     timestamp=2022-11-19 18:35:13.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9347387552261353}), Detection(
#     state_vector=StateVector([[3.03692539],
#                               [1.07258465]]),
#     timestamp=2022-11-19 18:35:13.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9231438040733337}), Detection(
#     state_vector=StateVector([[ 5.78418685],
#                               [-1.7348643 ]]),
#     timestamp=2022-11-19 18:35:13.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999486207962036}), Detection(
#     state_vector=StateVector([[ 6.00658557],
#                               [-2.57715327]]),
#     timestamp=2022-11-19 18:35:13.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999666213989258}), Detection(
#     state_vector=StateVector([[ 0.43276346],
#                               [-1.55877474]]),
#     timestamp=2022-11-19 18:35:13.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.9962148070335388}), Detection(
#     state_vector=StateVector([[1.51289353],
#                               [0.65650732]]),
#     timestamp=2022-11-19 18:35:13.118096,
#     measurement_model=None,
#     metadata={'confidence': 0.999931812286377})})
# (datetime.datetime(2022, 11, 19, 18, 35, 13, 218096), {Detection(
#     state_vector=StateVector([[ 6.61347369],
#                               [-1.39234299]]),
#     timestamp=2022-11-19 18:35:13.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9980594515800476}), Detection(
#     state_vector=StateVector([[ 0.78098348],
#                               [-1.68375744]]),
#     timestamp=2022-11-19 18:35:13.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9815205931663513}), Detection(
#     state_vector=StateVector([[-0.18267716],
#                               [ 1.7629259 ]]),
#     timestamp=2022-11-19 18:35:13.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9555553197860718}), Detection(
#     state_vector=StateVector([[3.05238963],
#                               [1.06956737]]),
#     timestamp=2022-11-19 18:35:13.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9024515151977539}), Detection(
#     state_vector=StateVector([[ 5.76877595],
#                               [-1.69542934]]),
#     timestamp=2022-11-19 18:35:13.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999163150787354}), Detection(
#     state_vector=StateVector([[1.51798165],
#                               [0.65409106]]),
#     timestamp=2022-11-19 18:35:13.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.999936580657959}), Detection(
#     state_vector=StateVector([[ 6.02183348],
#                               [-2.57768466]]),
#     timestamp=2022-11-19 18:35:13.218096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999417066574097})})
# (datetime.datetime(2022, 11, 19, 18, 35, 13, 318096), {Detection(
#     state_vector=StateVector([[-0.19076475],
#                               [ 1.77723119]]),
#     timestamp=2022-11-19 18:35:13.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9665417075157166}), Detection(
#     state_vector=StateVector([[ 0.5342644 ],
#                               [-1.60154227]]),
#     timestamp=2022-11-19 18:35:13.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9587807059288025}), Detection(
#     state_vector=StateVector([[1.50306849],
#                               [0.65368066]]),
#     timestamp=2022-11-19 18:35:13.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999699592590332}), Detection(
#     state_vector=StateVector([[ 6.61568998],
#                               [-1.39412658]]),
#     timestamp=2022-11-19 18:35:13.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9989282488822937}), Detection(
#     state_vector=StateVector([[ 5.77313949],
#                               [-1.6763472 ]]),
#     timestamp=2022-11-19 18:35:13.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9998118281364441}), Detection(
#     state_vector=StateVector([[ 6.02283524],
#                               [-2.5441315 ]]),
#     timestamp=2022-11-19 18:35:13.318096,
#     measurement_model=None,
#     metadata={'confidence': 0.9999387264251709})})

# %% [markdown]
# ### Transition model

# %% [markdown]
# We begin our definition of the state-space models by defining the hidden state
# $\mathrm{x}_k$, i.e. the state that we wish to estimate:
#
# \begin{align}\mathrm{x}_k = [x_k, \dot{x}_k, y_k, \dot{y}_k]\end{align}
#
# where $x_k, y_k$ denote center or detection, with $\dot{x}_k, \dot{y}_k$ denoting their respective rate of change

# %%
from stonesoup.models.transition.linear import (
    CombinedLinearGaussianTransitionModel, ConstantVelocity)

transition_model = CombinedLinearGaussianTransitionModel(
    [ConstantVelocity(0.05), ConstantVelocity(0.05)])

# %%
#from stonesoup.models.transition.linear import (CombinedLinearGaussianTransitionModel,
#                                                ConstantVelocity, RandomWalk)
#t_models = [ConstantVelocity(20**2), ConstantVelocity(20**2), RandomWalk(20**2), RandomWalk(20**2)]
#transition_model = CombinedLinearGaussianTransitionModel(t_models)

# %% [markdown]
# ### Measurement model

# %%
from stonesoup.models.measurement.linear import LinearGaussian

measurement_model_covariance = np.diag([0.25, 0.25])
measurement_model = LinearGaussian(ndim_state=4, mapping=[0, 2],noise_covar=measurement_model_covariance)

# %% [markdown]
# ## Create the tracker components
# In this example a Kalman filter is used with global nearest neighbour (GNN) associator. Other
# options are, of course, available.

# %% [markdown]
# ### Predictor
# Initialise the predictor using the same transition model as generated the ground truth. Note you
# don't have to use the same model.

# %%
from stonesoup.predictor.kalman import KalmanPredictor
predictor = KalmanPredictor(transition_model)

# %% [markdown]
# ### Updater
# Initialise the updater using the same measurement model as generated the simulated detections.
# Note, again, you don't have to use the same model (noise covariance).

# %%
from stonesoup.updater.kalman import KalmanUpdater
updater = KalmanUpdater(measurement_model)

# %% [markdown]
# ### Data associator
# Initialise a hypothesiser which will rank predicted measurement - measurement pairs according to
# some measure.
# Initialise a Mahalanobis distance measure to facilitate this ranking.

# %%
from stonesoup.hypothesiser.distance import DistanceHypothesiser
from stonesoup.measures import Mahalanobis
hypothesiser = DistanceHypothesiser(predictor, updater, measure=Mahalanobis(), missed_distance=3)

# %% [markdown]
# Initialise the GNN with the hypothesiser.

# %%
from stonesoup.dataassociator.neighbour import GNNWith2DAssignment
data_associator = GNNWith2DAssignment(hypothesiser)

# %% [markdown]
# ### Initiator and Deleter
# Create deleter - get rid of anything with a covariance trace greater than 2

# %%
from stonesoup.deleter.error import CovarianceBasedDeleter
covariance_limit_for_delete = 2
deleter = CovarianceBasedDeleter(covar_trace_thresh=covariance_limit_for_delete)

# %% [markdown]
# Set a standard prior state and the minimum number of detections required to qualify for
# initiation

# %%
s_prior_state = GaussianState([[0], [0], [0], [0]], np.diag([0, 0.5, 0, 0.5]))
min_detections = 3

# %% [markdown]
# Initialise the initiator - use the 'full tracker' components specified above in the initiator.
# But note that other ones could be used if needed.

# %%
from stonesoup.initiator.simple import MultiMeasurementInitiator
initiator = MultiMeasurementInitiator(
    prior_state=s_prior_state,
    measurement_model=measurement_model,
    deleter=deleter,
    data_associator=data_associator,
    updater=updater,
    min_points=min_detections
)

# %% [markdown]
# ## Run the Tracker
# With the components created, the multi-target tracker component is created, constructed from
# the components specified above. This is logically the same as tracking code in the previous
# tutorial section `auto_tutorials/09_Initiators_&_Deleters:Running the Tracker`

# %%
from stonesoup.tracker.simple import MultiTargetTracker

tracker = MultiTargetTracker(
    initiator=initiator,
    deleter=deleter,
    detector=detector,
    data_associator=data_associator,
    updater=updater,
)

# %% [markdown]
# In the case of using (J)PDA like in `auto_tutorials/07_PDATutorial:Run the PDA Filter`
# and `auto_tutorials/08_JPDATutorial:Running the JPDA filter`, then the
# :class:`~.MultiTargetMixtureTracker` would be used instead on the
# :class:`~.MultiTargetTracker` used above.
#
# ### Plot the outputs
# We plot the ground truth, detections and the tracker output using the Stone Soup :class:`Plotter`.

# %%
groundtruth = set()
detections = set()
tracks = set()

for time, ctracks in tracker:
    #groundtruth.update(groundtruth_sim.groundtruth_paths)
    detections.update(detector.detections)
    tracks.update(ctracks)

# %%
from stonesoup.plotter import Plotterly

plotter = Plotterly()
#plotter.plot_ground_truths(groundtruth, mapping=[0, 2])
plotter.plot_measurements(detections, mapping=[0, 2])
plotter.plot_tracks(tracks, mapping=[0, 2])
plotter.fig
# Out:
# <div>                            <div id="31b30533-ca36-42d5-95dd-ab4074b786de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31b30533-ca36-42d5-95dd-ab4074b786de")) {                    Plotly.newPlot(                        "31b30533-ca36-42d5-95dd-ab4074b786de",                        [{"legendgroup":"Tracks","legendrank":300,"marker":{"symbol":["square","square","square","square","square","square","square","square","square","square","square","square","square","square","circle","square","square","square","square","square","square","square","circle","square","square","square","square","square","square","square","square","square","circle","square","square","square","square","square","square","square","square","square","square","square","square","square","square","square","square","square","circle","circle","square","square","square","square","square","square","square","square","square","square","square","square","square","circle","square","square","square","square","square","square","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","square","square","square","square","square","square","square","square","square","square","square","circle","square","square","square","square","square","square","circle","square","square","square","square","circle","square","square","square","square","circle","circle","square","circle","circle","circle","circle","circle","square","square","circle","circle","circle","circle","circle","circle","circle","circle","square","square","square","square","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","square","square","square","square","square","square","square","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","circle","square","square","square","square","square","square","square","square"]},"mode":"markers+lines","name":"Tracks","showlegend":true,"text":["GaussianStateUpdate<br>[[ 0.35854218]\n [ 0.        ]\n [-1.53810788]\n [ 0.        ]]<br>2022-11-19 18:35:00.725357","GaussianStateUpdate<br>[[ 0.5643571 ]\n [ 0.040555  ]\n [-1.63880099]\n [-0.01984117]]<br>2022-11-19 18:35:00.825357","GaussianStateUpdate<br>[[ 0.64668846]\n [ 0.08371992]\n [-1.67268038]\n [-0.0374297 ]]<br>2022-11-19 18:35:00.925357","GaussianStateUpdate<br>[[ 0.67924589]\n [ 0.10675027]\n [-1.68423722]\n [-0.04487038]]<br>2022-11-19 18:35:01.025357","GaussianStateUpdate<br>[[ 0.71566616]\n [ 0.13953959]\n [-1.69212558]\n [-0.04920233]]<br>2022-11-19 18:35:01.125357","GaussianStateUpdate<br>[[ 0.73852215]\n [ 0.15252344]\n [-1.70301403]\n [-0.05790713]]<br>2022-11-19 18:35:01.225357","GaussianStateUpdate<br>[[ 0.66032254]\n [ 0.01017069]\n [-1.67225546]\n [-0.00223262]]<br>2022-11-19 18:35:01.325357","GaussianStateUpdate<br>[[ 0.59143304]\n [-0.09541976]\n [-1.64105902]\n [ 0.0452253 ]]<br>2022-11-19 18:35:01.425357","GaussianStateUpdate<br>[[ 0.55272852]\n [-0.13790836]\n [-1.61987513]\n [ 0.06950019]]<br>2022-11-19 18:35:01.525357","GaussianStateUpdate<br>[[ 0.59351939]\n [-0.06223364]\n [-1.63128266]\n [ 0.0440484 ]]<br>2022-11-19 18:35:01.625357","GaussianStateUpdate<br>[[ 0.61803555]\n [-0.02190172]\n [-1.63608605]\n [ 0.03196671]]<br>2022-11-19 18:35:01.725357","GaussianStateUpdate<br>[[ 0.64680525]\n [ 0.01650125]\n [-1.64086932]\n [ 0.0220683 ]]<br>2022-11-19 18:35:01.825357","GaussianStateUpdate<br>[[ 0.68865654]\n [ 0.06371979]\n [-1.6671986 ]\n [-0.01144898]]<br>2022-11-19 18:35:01.925357","GaussianStateUpdate<br>[[ 0.71348705]\n [ 0.08431281]\n [-1.67152098]\n [-0.0149939 ]]<br>2022-11-19 18:35:02.025357","GaussianStatePrediction<br>[[ 0.72191833]\n [ 0.08431281]\n [-1.67302037]\n [-0.0149939 ]]<br>2022- ...
